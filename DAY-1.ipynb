# %% [markdown]
# # Headings
#
# # heading1
#
# ## heading2
#
# ### Heading3
#
# #### Heading4
#
#
# # Bold letters
#
# **Python**
#
# __Workshop__
#
# # Italic Letters
#
# *Apssdc*
#
# _Skill Development_
#
#
# # Both Bold And Italic
#
# ***Carporation***
#
#
# # How to Apply images
#
# **Offline-image**
#
# <img src="sample.png" height=300px width=300px>
#
# **Online Image**
#
# <img src="https://i1.wp.com/blogs.cfainstitute.org/investor/files/2019/07/Emotions-and-Decision-Making-Five-Steps-to-Improve-Your-Process.jpg?fit=1200%2C628&ssl=1" height=300px width=300px>
#
#
# # Links
#
# This my [Email](https://www.gmail.com)
#
#
# # Bullet Points
#
# + c
#     + variables
#     - files
#     * pointers
#
# - C#
#     + variables
#     - files
#     * pointers
#
# * python
#     + variables
#     - files
#     * regularExpression
#
# + R-Progrmming
#
# * cpp
#
#
# # ordered list
#
#
# 1. WebTechnoilogies
#
# 10. Programminglanguages
#
# 50. Middle Level
#
# 100. Database
#
# # backtick
#
# hi`hello`world

# %% [markdown]
# #  Introduction To Python Programming
#
# ## In python we have 5 different keys
#
# + Highlevel langugage
#
# + object Oriented Programming(OOPS)
#
# + Interpeted
#
# + Multipurpose Programming & scripting language
#
# + Dynamic Programming
#
#
# # Features fo Python
#
#
# + openSource
#
# + crossplatform like Windows,linux,ubuntu,mathentoish,ios,linuxmint
#
# + rapid
#
# # Name of python
#
# + Monty python flying circus
#
# # History of Python
#
# + python load as foundation in the year 1980's
#
# + In 1989 guido van russum python was  at CWI NetherLand
#
# + In 1991 published version 0.9.0 without any features
#
# + In 1994 Again rebublished version 1.0 with features of ananymous functions Lambda, Map,Filter,Reduce
#
# + In 2000 Again republished vaersion 2.0 with features of Data structures List,Tuple,Dictionary,set...
#
# + In 2008 Agian Republished version 3.0 (py3k) with garbage collection,fast warking,day by day updating
